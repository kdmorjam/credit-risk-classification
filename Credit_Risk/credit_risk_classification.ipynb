# %%
# Import the modules
import numpy as np
import pandas as pd
from pathlib import Path
from sklearn.metrics import balanced_accuracy_score, confusion_matrix, classification_report

# %% [markdown]
# ---

# %% [markdown]
# ## Split the Data into Training and Testing Sets

# %% [markdown]
# ### Step 1: Read the `lending_data.csv` data from the `Resources` folder into a Pandas DataFrame.

# %%
# Read the CSV file from the Resources folder into a Pandas DataFrame
df_lending = pd.read_csv("lending_data.csv")

# Review the DataFrame
df_lending.head()
# Out:
#    loan_size  interest_rate  borrower_income  debt_to_income  num_of_accounts  \
# 0    10700.0          7.672            52800        0.431818                5
# 1     8400.0          6.692            43600        0.311927                3
# 2     9000.0          6.963            46100        0.349241                3
# 3    10700.0          7.664            52700        0.430740                5
# 4    10800.0          7.698            53000        0.433962                5
#
#    derogatory_marks  total_debt  loan_status
# 0                 1       22800            0
# 1                 0       13600            0
# 2                 0       16100            0
# 3                 1       22700            0
# 4                 1       23000            0

# %% [markdown]
# ### Step 2: Create the labels set (`y`)  from the “loan_status” column, and then create the features (`X`) DataFrame from the remaining columns.

# %%
# Separate the data into labels and features

# Separate the y variable, the labels
y = df_lending["loan_status"].values.reshape(-1, 1)

# Separate the X variable, the features
X = df_lending.copy()
X.drop("loan_status", axis=1, inplace=True)

# %%
# Review the y variable Series
y[:5]
# Out:
# array([[0],
#        [0],
#        [0],
#        [0],
#        [0]])

# %%
# Review the X variable DataFrame
X.head()
# Out:
#    loan_size  interest_rate  borrower_income  debt_to_income  num_of_accounts  \
# 0    10700.0          7.672            52800        0.431818                5
# 1     8400.0          6.692            43600        0.311927                3
# 2     9000.0          6.963            46100        0.349241                3
# 3    10700.0          7.664            52700        0.430740                5
# 4    10800.0          7.698            53000        0.433962                5
#
#    derogatory_marks  total_debt
# 0                 1       22800
# 1                 0       13600
# 2                 0       16100
# 3                 1       22700
# 4                 1       23000

# %% [markdown]
# ### Step 3: Check the balance of the labels variable (`y`) by using the `value_counts` function.

# %%
# Check the balance of our target values
unique, counts = np.unique(y, return_counts=True)
print(np.asarray((unique, counts)).T)
# Out:
# [[    0 75036]
#  [    1  2500]]

# %% [markdown]
# ### Step 4: Split the data into training and testing datasets by using `train_test_split`.

# %%
# Import the train_test_learn module
from sklearn.model_selection import train_test_split

# Split the data using train_test_split
# Assign a random_state of 1 to the function
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7)

# %% [markdown]
# ---

# %% [markdown]
# ## Create a Logistic Regression Model with the Original Data

# %% [markdown]
# ###  Step 1: Fit a logistic regression model by using the training data (`X_train` and `y_train`).

# %%
# Import the LogisticRegression module from SKLearn
from sklearn.linear_model import LogisticRegression

# Instantiate the Logistic Regression model
# Assign a random_state parameter of 1 to the model
lr_train_model = LogisticRegression()

# Fit the model using training data
lr_train_model.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %% [markdown]
# ### Step 2: Save the predictions on the testing data labels by using the testing feature data (`X_test`) and the fitted model.

# %%
# Make a prediction using the testing data
y_pred_test = lr_train_model.predict(X_test)

# %% [markdown]
# ### Step 3: Evaluate the model’s performance by doing the following:
#
# * Calculate the accuracy score of the model.
#
# * Generate a confusion matrix.
#
# * Print the classification report.

# %%
# Print the balanced_accuracy score of the model
print(balanced_accuracy_score(y_test, y_pred_test))
# Out:
# 0.9481269535981227

# %%
# Generate a confusion matrix for the model
cm = confusion_matrix(y_test, y_pred_test)
cm_df = pd.DataFrame(
    cm, index=["Actual 0", "Actual 1"], columns=["Predicted 0", "Predicted 1"]
)
display(cm_df)
# Out:
#           Predicted 0  Predicted 1
# Actual 0        22347          121
# Actual 1           78          715

# %%
on size,

# %%
# Print the classification report for the model
target_names=['Healthy loan', 'High-risk loan']
print(classification_report(y_test, y_pred_test, target_names=target_names))
# Out:
#                 precision    recall  f1-score   support
#
#   Healthy loan       1.00      0.99      1.00     22468
# High-risk loan       0.86      0.90      0.88       793
#
#       accuracy                           0.99     23261
#      macro avg       0.93      0.95      0.94     23261
#   weighted avg       0.99      0.99      0.99     23261

# %% [markdown]
# ### Step 4: Answer the following question.

# %% [markdown]
# **Question:** How well does the logistic regression model predict both the `0` (healthy loan) and `1` (high-risk loan) labels?
#
# **Answer:** Accuracy of the model was at 94.8%. However, prediction for helthy loans was 100%, but high-risk was at 86%

# %% [markdown]
# ---

# %% [markdown]
# ## Predict a Logistic Regression Model with Resampled Training Data

# %% [markdown]
# ### Step 1: Use the `RandomOverSampler` module from the imbalanced-learn library to resample the data. Be sure to confirm that the labels have an equal number of data points.

# %%
# Import the RandomOverSampler module form imbalanced-learn
from imblearn.over_sampling import RandomOverSampler

# Instantiate the random oversampler model
# # Assign a random_state parameter of 1 to the model
oversample = RandomOverSampler(random_state=1)


# Fit the original training data to the random_oversampler model
X_resample, y_resample = oversample.fit_resample(X_train, y_train)

# %%
X_resample
# Out:
#         loan_size  interest_rate  borrower_income  debt_to_income  \
# 0          9900.0          7.331            49600        0.395161
# 1          9300.0          7.093            47300        0.365751
# 2          8300.0          6.658            43300        0.307159
# 3          8600.0          6.761            44200        0.321267
# 4          9100.0          7.001            46500        0.354839
# ...           ...            ...              ...             ...
# 105131    20000.0         11.629            90000        0.666667
# 105132    20100.0         11.647            90200        0.667406
# 105133    20800.0         11.948            93000        0.677419
# 105134    20200.0         11.716            90900        0.669967
# 105135    20200.0         11.692            90600        0.668874
#
#         num_of_accounts  derogatory_marks  total_debt
# 0                     4                 0       19600
# 1                     3                 0       17300
# ...

# %%
# Count the distinct values of the resampled labels data
unique, counts = np.unique(y_resample, return_counts=True)
print(np.asarray((unique, counts)).T)
# Out:
# [[    0 52568]
#  [    1 52568]]

# %% [markdown]
# ### Step 2: Use the `LogisticRegression` classifier and the resampled data to fit the model and make predictions.

# %%
# Instantiate the Logistic Regression model
# Assign a random_state parameter of 1 to the model
resample_model = LogisticRegression()


# Fit the model using the resampled training data
resample_model.fit(X_resample, y_resample)

# Make a prediction using the testing data
y_pred_sample = resample_model.predict(X_test)

# %% [markdown]
# ### Step 3: Evaluate the model’s performance by doing the following:
#
# * Calculate the accuracy score of the model.
#
# * Generate a confusion matrix.
#
# * Print the classification report.

# %%
# Print the balanced_accuracy score of the model
print(balanced_accuracy_score(y_test, y_pred_sample))
# Out:
# 0.9931903712406109

# %%
# Generate a confusion matrix for the model
cm_sample = confusion_matrix(y_test, y_pred_sample)
cm_sample_df = pd.DataFrame(
    cm_sample, index=["Actual 0", "Actual 1"], columns=["Predicted 0", "Predicted 1"]
)
display(cm_sample_df)
# Out:
#           Predicted 0  Predicted 1
# Actual 0        22389          131
# Actual 1            2          739

# %%
# Print the classification report for the model
print(classification_report(y_test, y_pred_sample,target_names=target_names))
# Out:
#                 precision    recall  f1-score   support
#
#   Healthy loan       1.00      0.99      1.00     22468
# High-risk loan       0.85      0.99      0.92       793
#
#       accuracy                           0.99     23261
#      macro avg       0.93      0.99      0.96     23261
#   weighted avg       0.99      0.99      0.99     23261

# %% [markdown]
# ### Step 4: Answer the following question

# %% [markdown]
# **Question:** How well does the logistic regression model, fit with oversampled data, predict both the `0` (healthy loan) and `1` (high-risk loan) labels?
#
# **Answer:** This model was able to predict healthy loans at 100%, but high-risk loans at 85%.
